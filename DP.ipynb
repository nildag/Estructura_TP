# %%
import pandas as pd

# %%
# Cargar el DataFrame desde el archivo CSV
df = pd.read_csv('web_scraping_citas.csv')

# %%
# Visualizar las primeras filas del DataFrame
print("Primeras 5 filas del DataFrame:")
df.head()
# Out:
# Primeras 5 filas del DataFrame:
#                                               Titulo  \
# 0  Digital twin: Enabling technologies, challenge...
# 1  Deep learning in glaucoma with optical coheren...
# 2  Machine learning and deep learning application...
# 3         A survey of complex-valued neural networks
# 4  Ensemble learning of diffractive optical networks
#
#                                                Autor  \
# 0  Fuller, Aidan and Fan, Zhong and Day, Charles ...
# 1  Ran, An Ran and Tham, Clement C and Chan, Poem...
# 2  Sharma, Neha and Sharma, Reecha and Jindal, Neeru
# 3    Bassey, Joshua and Qian, Lijun and Li, Xianfang
# 4  Rahman, Md Sadman Sakib and Li, Jingxi and Men...
#
#                            Revista   Año                             Editor  \
# 0                      IEEE access  2020                               IEEE
# 1                              Eye  2021  Nature Publishing Group UK London
# 2   Global Transitions Proceedings  2021                           Elsevier
# 3  arXiv preprint arXiv:2101.12249  2021                                NaN
# 4   Light: Science \& Applications  2021  Nature Publishing Group UK London
#
#                                                  URL  Citado
# 0  https://scholar.google.com/scholar?cites=14409...  1159.0
# 1  https://scholar.google.com/scholar?cites=89540...    69.0
# 2  https://scholar.google.com/scholar?cites=16263...   151.0
# 3  https://scholar.google.com/scholar?cites=12448...    86.0
# 4  https://scholar.google.com/scholar?cites=94925...    82.0

# %%
#Ordenar el DataFrame por número de citas en orden descendente
df_ordenado = df.sort_values(by='Citado', ascending=False)
df_ordenado.head()
# Out:
#                                               Titulo  \
# 0  Digital twin: Enabling technologies, challenge...
# 2  Machine learning and deep learning application...
# 3         A survey of complex-valued neural networks
# 4  Ensemble learning of diffractive optical networks
# 1  Deep learning in glaucoma with optical coheren...
#
#                                                Autor  \
# 0  Fuller, Aidan and Fan, Zhong and Day, Charles ...
# 2  Sharma, Neha and Sharma, Reecha and Jindal, Neeru
# 3    Bassey, Joshua and Qian, Lijun and Li, Xianfang
# 4  Rahman, Md Sadman Sakib and Li, Jingxi and Men...
# 1  Ran, An Ran and Tham, Clement C and Chan, Poem...
#
#                            Revista   Año                             Editor  \
# 0                      IEEE access  2020                               IEEE
# 2   Global Transitions Proceedings  2021                           Elsevier
# 3  arXiv preprint arXiv:2101.12249  2021                                NaN
# 4   Light: Science \& Applications  2021  Nature Publishing Group UK London
# 1                              Eye  2021  Nature Publishing Group UK London
#
#                                                  URL  Citado
# 0  https://scholar.google.com/scholar?cites=14409...  1159.0
# 2  https://scholar.google.com/scholar?cites=16263...   151.0
# 3  https://scholar.google.com/scholar?cites=12448...    86.0
# 4  https://scholar.google.com/scholar?cites=94925...    82.0
# 1  https://scholar.google.com/scholar?cites=89540...    69.0

# %%
# Seleccionar los 10 artículos con más citas
top_10_citados = df_ordenado.head(10)
top_10_citados
# Out:
#                                               Titulo  \
# 0  Digital twin: Enabling technologies, challenge...
# 2  Machine learning and deep learning application...
# 3         A survey of complex-valued neural networks
# 4  Ensemble learning of diffractive optical networks
# 1  Deep learning in glaucoma with optical coheren...
# 5  Machine learning activation energies of chemic...
# 6  Deep learning for manufacturing sustainability...
# 7  Smartphone-based platforms implementing microf...
#
#                                                Autor  \
# 0  Fuller, Aidan and Fan, Zhong and Day, Charles ...
# 2  Sharma, Neha and Sharma, Reecha and Jindal, Neeru
# 3    Bassey, Joshua and Qian, Lijun and Li, Xianfang
# 4  Rahman, Md Sadman Sakib and Li, Jingxi and Men...
# 1  Ran, An Ran and Tham, Clement C and Chan, Poem...
# 5  Lewis-Atwell, Toby and Townsend, Piers A and G...
# 6  Jamwal, Anbesh and Agrawal, Rajeev and Sharma,...
# 7  Wang, Bangfeng and Li, Yiwei and Zhou, Mengfan...
#
#                                              Revista   Año  \
# 0                                        IEEE access  2020
# 2                     Global Transitions Proceedings  2021
# 3                    arXiv preprint arXiv:2101.12249  2021
# 4                     Light: Science \& Applications  2021
# 1                                                Eye  2021
# 5  Wiley Interdisciplinary Reviews: Computational...  2022
# 6  International Journal of Information Managemen...  2022
# 7                              Nature Communications  2023
#
#                               Editor  \
# 0                               IEEE
# 2                           Elsevier
# 3                                NaN
# 4  Nature Publishing Group UK London
# 1  Nature Publishing Group UK London
# 5               Wiley Online Library
# 6                           Elsevier
# 7  Nature Publishing Group UK London
#
#                                                  URL  Citado
# 0  https://scholar.google.com/scholar?cites=14409...  1159.0
# 2  https://scholar.google.com/scholar?cites=16263...   151.0
# 3  https://scholar.google.com/scholar?cites=12448...    86.0
# 4  https://scholar.google.com/scholar?cites=94925...    82.0
# 1  https://scholar.google.com/scholar?cites=89540...    69.0
# 5  https://scholar.google.com/scholar?cites=11023...    30.0
# 6  https://scholar.google.com/scholar?cites=13503...    19.0
# 7  https://scholar.google.com/scholar?cites=44746...    17.0

# %%
# Crear un nuevo DataFrame con las columnas deseadas
resultado = top_10_citados[['Citado', 'Año', 'Titulo', 'Revista']]
resultado
# Out:
#    Citado   Año                                             Titulo  \
# 0  1159.0  2020  Digital twin: Enabling technologies, challenge...
# 2   151.0  2021  Machine learning and deep learning application...
# 3    86.0  2021         A survey of complex-valued neural networks
# 4    82.0  2021  Ensemble learning of diffractive optical networks
# 1    69.0  2021  Deep learning in glaucoma with optical coheren...
# 5    30.0  2022  Machine learning activation energies of chemic...
# 6    19.0  2022  Deep learning for manufacturing sustainability...
# 7    17.0  2023  Smartphone-based platforms implementing microf...
#
#                                              Revista
# 0                                        IEEE access
# 2                     Global Transitions Proceedings
# 3                    arXiv preprint arXiv:2101.12249
# 4                     Light: Science \& Applications
# 1                                                Eye
# 5  Wiley Interdisciplinary Reviews: Computational...
# 6  International Journal of Information Managemen...
# 7                              Nature Communications

# %%
# Guardar el resultado en un archivo CSV
resultado.to_csv('top_10_articulos_citados.csv', index=False)

# %%
###########################

# %%
# Solicitar al usuario que ingrese la palabra clave de interés
palabra_clave = input("Ingrese la palabra clave de interés: ")
# Out:
# Ingrese la palabra clave de interés: Machine

# %%
# Filtrar los artículos que contienen la palabra clave en el título
resultados = df[df['Titulo'].str.contains(palabra_clave, case=False, na=False, regex=True)]

# %%
# Crear un DataFrame con los títulos y URLs de los artículos que coinciden
resultados_filtrados = resultados[['Titulo', 'URL']]

# %%
# Guardar el resultado en un archivo CSV
resultados_filtrados.to_csv('resultados_palabra_clave.csv', index=False)

print("Se han guardado los resultados en 'resultados_palabra_clave.csv'.")
# Out:
# Se han guardado los resultados en 'resultados_palabra_clave.csv'.

# %%
resultados_filtrados
# Out:
#                                               Titulo  \
# 2  Machine learning and deep learning application...
# 5  Machine learning activation energies of chemic...
#
#                                                  URL
# 2  https://scholar.google.com/scholar?cites=16263...
# 5  https://scholar.google.com/scholar?cites=11023...

# %%
############################

# %%
# Extraer la lista de autores
autores = df['Autor'].str.split(' and ')

# %%
# Crear una lista plana de autores
lista_autores = [autor for autores_articulo in autores.dropna() for autor in autores_articulo]

# %%
# Contar la frecuencia de cada autor
frecuencia_autores = pd.Series(lista_autores).value_counts().reset_index()
frecuencia_autores.columns = ['Autor', 'Frecuencia']

# %%
# Ordenar la lista de autores por el número de veces que aparecen
frecuencia_autores = frecuencia_autores.sort_values(by='Frecuencia', ascending=False)

# %%
# Guardar el resultado en un archivo CSV
frecuencia_autores.to_csv('autores_frecuencia.csv', index=False)

print("Se ha guardado la frecuencia de los autores en 'autores_frecuencia.csv'.")
# Out:
# Se ha guardado la frecuencia de los autores en 'autores_frecuencia.csv'.

# %%
frecuencia_autores
# Out:
#                       Autor  Frecuencia
# 0             Fuller, Aidan           1
# 29          Cheung, Carol Y           1
# 22             Day, Charles           1
# 23            Barlow, Chris           1
# 24              Ran, An Ran           1
# 25          Tham, Clement C           1
# 26           Chan, Poemen P           1
# 27          Cheng, Ching-Yu           1
# 28          Tham, Yih-Chung           1
# 30               Li, Jingxi           1
# 20               Fan, Zhong           1
# 31             Sharma, Neha           1
# 32           Sharma, Reecha           1
# 33            Jindal, Neeru           1
# 34           Bassey, Joshua           1
# 35              Qian, Lijun           1
# 36             Li, Xianfang           1
# 37  Rahman, Md Sadman Sakib           1
# 21     Rim, Tyler Hyungtaek           1
# 19             Mengu, Deniz           1
# 1                 Li, Yiwei           1
# 9             Zhou, Mengfan           1
# 2        Lewis-Atwell, Toby           1
# 3         Townsend, Piers A           1
# 4        Grayson, Matthew N           1
# 5            Jamwal, Anbesh           1
# 6           Agrawal, Rajeev           1
# 7            Sharma, Monica           1
# 8            Wang, Bangfeng           1
# 10           Rivenson, Yair           1
# 18           Ozcan, Aydogan           1
# 11              Han, Yulong           1
# 12            Zhang, Mingyu           1
# 13            Gao, Zhaolong           1
# 14               Liu, Zetai           1
# 15               Chen, Peng           1
# 16                  Du, Wei           1
# 17           Zhang, Xingcai           1
# 38                   others           1

# %%
###############################

# %%
# !pip install matplotlib wordcloud
# Out:
# Requirement already satisfied: matplotlib in d:\programasfacultad\anaconda\lib\site-packages (3.7.1)
# Requirement already satisfied: wordcloud in d:\programasfacultad\anaconda\lib\site-packages (1.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programasfacultad\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\programasfacultad\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
import re

# %%
# Obtener los títulos de los artículos
titulos = df['Titulo']

# Crear una lista de palabras significativas para omitir
palabras_omitir = ['a', 'an', 'the', 'in', 'of', 'for', 'and', 'on', 'with', 'to', 'by', 'at']

# Función para procesar los títulos y extraer palabras significativas
def procesar_titulo(titulo):
    palabras = re.findall(r'\w+', titulo.lower())
    palabras_filtradas = [palabra for palabra in palabras if palabra not in palabras_omitir]
    return palabras_filtradas

# Procesar los títulos y contar las palabras
todas_palabras = [palabra for titulo in titulos for palabra in procesar_titulo(titulo)]
contador_palabras = Counter(todas_palabras)

# Crear un gráfico de nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(contador_palabras)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nube de Palabras en Títulos de Artículos')
plt.show()

# Contar la cantidad de artículos recuperados por año
conteo_anios = df['Año'].value_counts().sort_index()

# Crear un gráfico de barras para la cantidad de artículos por año
plt.figure(figsize=(10, 5))
conteo_anios.plot(kind='bar')
plt.title('Cantidad de Artículos por Año de Publicación')
plt.xlabel('Año')
plt.ylabel('Cantidad de Artículos')
plt.xticks(rotation=45)
plt.show()
